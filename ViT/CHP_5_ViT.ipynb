# %%
import os
from collections import Counter

data_dir = '/kaggle/input/fine-grained-fruit-quality-assessment/train/train'

class_counts = {}

for class_name in os.listdir(data_dir):
    class_folder = os.path.join(data_dir, class_name)
    if os.path.isdir(class_folder):
        num_images = len(os.listdir(class_folder))
        class_counts[class_name] = num_images

total_images = sum(class_counts.values())

class_proportions = {class_name: count / total_images for class_name, count in class_counts.items()}

print("Class Proportions:")
for class_name, proportion in class_proportions.items():
    print(f"{class_name}: {proportion:.2f}")
# Out:
# Class Proportions:
# tomato_fully_ripened: 0.01
# tomato_half_ripened: 0.01
# banana_overripe: 0.21
# banana_rotten: 0.30
# banana_unripe: 0.21
# banana_ripe: 0.22
# tomato_green: 0.05

# %% [markdown]
# ## ViT Model in tensorflow

# %% [markdown]
# ![image.png](attachment:39ac3f66-7766-4178-9eaa-6908fabca880.png)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import mixed_precision
from tensorflow.keras import layers, Model
import pandas as pd
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
import os
# Out:
# 2025-05-12 20:31:37.578935: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747081897.761383      31 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747081897.819517      31 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# Set random seeds for reproducibility
tf.random.set_seed(42)
np.random.seed(42)

# Configuration
IMG_SIZE = (224, 224)
PATCH_SIZE = 16
PROJECTION_DIM = 128
NUM_HEADS = 8
TRANSFORMER_LAYERS = 8
MLP_HEAD_UNITS = [2048, 1024]
DROPOUT_RATE = 0.1

# Custom Layers for Vision Transformer
class PatchCreation(layers.Layer):
    def __init__(self, patch_size):
        super(PatchCreation, self).__init__()
        self.patch_size = patch_size
        
    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID"
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches

class PatchEmbedding(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super(PatchEmbedding, self).__init__()
        self.num_patches = num_patches
        self.projection_dim = projection_dim
        self.projection = layers.Dense(projection_dim)
        
    def call(self, patches):
        return self.projection(patches)

class PositionEmbedding(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super(PositionEmbedding, self).__init__()
        self.num_patches = num_patches
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )
        
    def call(self, patches):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = patches + self.position_embedding(positions)
        return encoded

class TransformerEncoderBlock(layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, dropout=0.1):
        super(TransformerEncoderBlock, self).__init__()
        
        self.attention = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=dropout
        )
        
        self.layernorm1 = layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = layers.LayerNormalization(epsilon=1e-6)
        
        self.mlp = tf.keras.Sequential([
            layers.Dense(ff_dim, activation="gelu"),
            layers.Dropout(dropout),
            layers.Dense(embed_dim),
            layers.Dropout(dropout)
        ])
        
    def call(self, inputs, training=True):
        # Apply Layer Normalization before attention
        x1 = self.layernorm1(inputs)
        attention_output = self.attention(x1, x1, training=training)
        x2 = attention_output + inputs
        
        # Apply Layer Normalization before MLP
        x3 = self.layernorm2(x2)
        x4 = self.mlp(x3, training=training)
        return x2 + x4

# Main Vision Transformer Model
def create_vit_model(input_shape, patch_size, num_classes, projection_dim, 
                     num_heads, transformer_layers, mlp_head_units, dropout=0.1):
    # Calculate number of patches
    num_patches = (input_shape[0] // patch_size) * (input_shape[1] // patch_size)
    
    inputs = layers.Input(shape=input_shape)
    
    # No normalization layer since we already normalized in generator
    # Create patches from images
    patches = PatchCreation(patch_size)(inputs)
    
    # Create patch embeddings
    embedding_layer = PatchEmbedding(num_patches, projection_dim)
    embeddings = embedding_layer(patches)
    
    # Add positional embeddings
    position_embedding = PositionEmbedding(num_patches, projection_dim)
    encoded_patches = position_embedding(embeddings)
    
    # Add dropout after embeddings
    x = layers.Dropout(dropout)(encoded_patches)
    
    # Create Transformer Encoder blocks
    for _ in range(transformer_layers):
        x = TransformerEncoderBlock(
            projection_dim, num_heads, projection_dim * 4, dropout
        )(x)
    
    # Layer Normalization and Global Average Pooling
    representation = layers.LayerNormalization(epsilon=1e-6)(x)
    representation = layers.GlobalAvgPool1D()(representation)
    
    # MLP Head for classification
    features = representation
    for units in mlp_head_units:
        features = layers.Dense(units, activation="gelu")(features)
        features = layers.Dropout(dropout)(features)
    
    # Final classification layer
    outputs = layers.Dense(num_classes, activation="softmax")(features)
    
    model = Model(inputs=inputs, outputs=outputs)
    return model

# Function to handle class imbalance
def calculate_class_weights(generator):
    # Get labels from generator
    y = []
    num_samples = 0
    
    for i in range(len(generator)):
        if num_samples >= generator.samples:
            break
        batch_x, batch_y = generator[i]
        y.extend(batch_y.astype(np.int64))
        num_samples += len(batch_y)
    
    # Reset generator
    generator.reset()
    
    y = np.array(y)
    class_counts = np.bincount(y)
    total_samples = np.sum(class_counts)
    n_classes = len(class_counts)
    
    # Calculate class weights
    class_weights = {}
    for i in range(n_classes):
        if class_counts[i] > 0:
            class_weights[i] = total_samples / (n_classes * class_counts[i])
        else:
            class_weights[i] = 1.0
    
    return class_weights

# Function to analyze class distribution
def analyze_class_distribution(generator):
    """Analyze and visualize class distribution"""
    labels = []
    for i in range(len(generator)):
        batch_x, batch_y = generator[i]
        labels.extend(batch_y)
    
    # Reset generator after reading
    generator.reset()
    
    # Plot class distribution
    plt.figure(figsize=(15, 6))
    
    unique, counts = np.unique(labels, return_counts=True)
    class_names = list(generator.class_indices.keys())
    
    plt.bar(range(len(counts)), counts)
    plt.xticks(range(len(class_names)), class_names, rotation=90)
    plt.title('Class Distribution in Training Data')
    plt.xlabel('Class')
    plt.ylabel('Number of Samples')
    plt.tight_layout()
    plt.show()
    
    print("Class distribution:")
    for i, count in enumerate(counts):
        print(f"{class_names[i]}: {count} samples")
    
    # Check for class imbalance
    min_samples = np.min(counts)
    max_samples = np.max(counts)
    imbalance_ratio = max_samples / min_samples
    
    print(f"Imbalance ratio (max/min): {imbalance_ratio:.2f}")
    
    return labels, counts

# Compile and train the model
def compile_and_train_model(model, train_data, val_data, class_weights, epochs=50):
    # Define callbacks
    callbacks = [
        ModelCheckpoint(
            'best_vit_model.keras',
            monitor='val_accuracy',
            save_best_only=True,
            verbose=1
        ),
        EarlyStopping(
            monitor='val_loss',
            patience=10,
            restore_best_weights=True,
            verbose=1
        ),
        ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.2,
            patience=5,
            min_lr=1e-6,
            verbose=1
        )
    ]
    
    # Compile model
    model.compile(
        optimizer=tf.keras.optimizers.AdamW(learning_rate=1e-4, weight_decay=1e-5),
        loss='sparse_categorical_crossentropy',  # Use sparse since class_mode='sparse'
        metrics=['accuracy']
    )
    
    # Train the model
    history = model.fit(
        train_data,
        validation_data=val_data,
        epochs=epochs,
        class_weight=class_weights,
        callbacks=callbacks,
        verbose=1
    )
    
    return history

# Plot training history
def plot_training_history(history):
    plt.figure(figsize=(15, 5))
    
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Val Accuracy')
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    
    plt.tight_layout()
    plt.show()

# Prediction and submission functions
def create_submission_csv(model, test_generator, output_file='/kaggle/working/submission.csv'):
    """Create submission file for Kaggle"""
    
    # Get predictions
    predictions = model.predict(test_generator, verbose=1)
    predicted_classes = np.argmax(predictions, axis=1)
    
    # Get file paths and ids
    test_generator.reset()
    filenames = test_generator.filenames
    
    # Extract ids from filenames (assuming format like: id.jpg)
    # ids = [os.path.splitext(os.path.basename(filename))[0] for filename in filenames]
    ids = [os.path.basename(filename) for filename in filenames]  

    # Create submission dataframe
    submission_df = pd.DataFrame({
        'ImageID': ids,
        'Class': predicted_classes
    })
    
    # Save to CSV
    submission_df.to_csv(output_file, index=False)
    print(f"Submission saved to {output_file}")
    print("\nFirst 10 predictions:")
    print(submission_df.head(10))
    
    return submission_df

# Function to evaluate model on validation set
def evaluate_model(model, val_generator):
    """Evaluate model performance"""
    val_loss, val_accuracy = model.evaluate(val_generator, verbose=1)
    print(f"Validation Loss: {val_loss:.4f}")
    print(f"Validation Accuracy: {val_accuracy:.4f}")
    
    return val_loss, val_accuracy

# %%
# Set random seeds for reproducibility
tf.random.set_seed(42)
np.random.seed(42)

# Check for GPU availability
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

# Enable mixed precision for faster training if GPU is available
if len(tf.config.list_physical_devices('GPU')) > 0:
    try:
        policy = tf.keras.mixed_precision.Policy('mixed_float16')
        tf.keras.mixed_precision.set_policy(policy)
        print('Mixed precision enabled')
    except:
        print('Mixed precision not available')

# Define constants
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS = 50

# Your existing data generators
data = ImageDataGenerator(
    rescale=1./255,              # Normalize pixel values
    validation_split=0.2,        # Reserve 20% for validation
    rotation_range=20,           # Randomly rotate images by up to 20 degrees
    zoom_range=0.1,              # Slight zooming
    width_shift_range=0.1,       # Slight horizontal shift
    height_shift_range=0.1,      # Slight vertical shift
    shear_range=0.1,             # Shearing transformation
    horizontal_flip=True,        # Randomly flip images horizontally
    fill_mode='nearest'          # Fill in missing pixels after rotation/shift
)

# Load training data
trainData = data.flow_from_directory(
    '/kaggle/input/fine-grained-fruit-quality-assessment/train/train',
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='sparse',  # Uses label encoding
    shuffle=True,
    subset='training'  # This gives 80%
)

# Load validation data
valData = data.flow_from_directory(
    '/kaggle/input/fine-grained-fruit-quality-assessment/train/train',
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='sparse',
    shuffle=False,
    subset='validation'  # This gives 20%
)

# Load test data
testData = data.flow_from_directory(
    '/kaggle/input/fine-grained-fruit-quality-assessment/test',
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode=None,  # No labels for test data
    shuffle=False
)

# Display dataset information
print(f"Training data: {trainData.samples} samples")
print(f"Validation data: {valData.samples} samples")
print(f"Test data: {testData.samples} samples")
print(f"Number of classes: {len(trainData.class_indices)}")
print(f"Classes: {list(trainData.class_indices.keys())}")
# Out:
# Num GPUs Available:  1
# Mixed precision not available
# Found 5917 images belonging to 7 classes.
# Found 1478 images belonging to 7 classes.
# Found 2484 images belonging to 1 classes.
# Training data: 5917 samples
# Validation data: 1478 samples
# Test data: 2484 samples
# Number of classes: 7
# Classes: ['banana_overripe', 'banana_ripe', 'banana_rotten', 'banana_unripe', 'tomato_fully_ripened', 'tomato_green', 'tomato_half_ripened']

# %%
print(trainData.class_indices)
# Out:
# {'banana_overripe': 0, 'banana_ripe': 1, 'banana_rotten': 2, 'banana_unripe': 3, 'tomato_fully_ripened': 4, 'tomato_green': 5, 'tomato_half_ripened': 6}

# %%
# Analyze class distribution
print("\nAnalyzing class distribution...")
labels, counts = analyze_class_distribution(trainData)
# Out:
# Analyzing class distribution...
# Class distribution:
# banana_overripe: 1240 samples
# banana_ripe: 1280 samples
# banana_rotten: 1766 samples
# banana_unripe: 1218 samples
# tomato_fully_ripened: 44 samples
# tomato_green: 297 samples
# tomato_half_ripened: 72 samples
# Imbalance ratio (max/min): 40.14

# %%
# Calculate class weights to handle imbalanced data
print("\nCalculating class weights...")
class_weights = calculate_class_weights(trainData)
print("Class weights:", class_weights)
# Out:
# Calculating class weights...
# Class weights: {0: 0.6816820276497696, 1: 0.6603794642857143, 2: 0.4786442323248665, 3: 0.6939948393150364, 4: 19.211038961038962, 5: 2.846079846079846, 6: 11.740079365079366}

# %%
# Create the Vision Transformer model
print("\nCreating Vision Transformer model...")
NUM_CLASSES = len(trainData.class_indices)
INPUT_SHAPE = (*IMG_SIZE, 3)

model = create_vit_model(
    input_shape=INPUT_SHAPE,
    patch_size=16,
    num_classes=NUM_CLASSES,
    projection_dim=128,
    num_heads=8,
    transformer_layers=8,
    mlp_head_units=[2048, 1024],
    dropout=0.1
)

# Print model summary
print("\nModel Summary:")
model.summary()
# Out:
# Creating Vision Transformer model...
# I0000 00:00:1747082271.744192      31 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model Summary:
# Model: "functional_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ patch_creation (PatchCreation)       │ (None, None, 768)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ patch_embedding (PatchEmbedding)     │ (None, None, 128)           │          98,432 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ position_embedding                   │ (None, 196, 128)            │          25,088 │
# │ (PositionEmbedding)                  │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 196, 128)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ transformer_encoder_block            │ (None, 196, 128)            │         659,712 │
# │ (TransformerEncoderBlock)            │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ transformer_encoder_block_1          │ (None, 196, 128)            │         659,712 │
# │ (TransformerEncoderBlock)            │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ transformer_encoder_block_2          │ (None, 196, 128)            │         659,712 │
# │ (TransformerEncoderBlock)            │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ transformer_encoder_block_3          │ (None, 196, 128)            │         659,712 │
# │ (TransformerEncoderBlock)            │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ transformer_encoder_block_4          │ (None, 196, 128)            │         659,712 │
# │ (TransformerEncoderBlock)            │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ transformer_encoder_block_5          │ (None, 196, 128)            │         659,712 │
# │ (TransformerEncoderBlock)            │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ transformer_encoder_block_6          │ (None, 196, 128)            │         659,712 │
# │ (TransformerEncoderBlock)            │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ transformer_encoder_block_7          │ (None, 196, 128)            │         659,712 │
# │ (TransformerEncoderBlock)            │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ layer_normalization_16               │ (None, 196, 128)            │             256 │
# │ (LayerNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling1d             │ (None, 128)                 │               0 │
# │ (GlobalAveragePooling1D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_17 (Dense)                     │ (None, 2048)                │         264,192 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_25 (Dropout)                 │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_18 (Dense)                     │ (None, 1024)                │       2,098,176 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_26 (Dropout)                 │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_19 (Dense)                     │ (None, 7)                   │           7,175 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7,771,015 (29.64 MB)
#  Trainable params: 7,771,015 (29.64 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
print("\nStarting training...")
history = compile_and_train_model(
    model=model,
    train_data=trainData,
    val_data=valData,
    class_weights=class_weights,
    epochs=EPOCHS
)
# Out:
# Starting training...
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1747082776.026207     118 service.cc:148] XLA service 0x7b2888220c10 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1747082776.027084     118 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1747082779.254095     118 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   1/185 ━━━━━━━━━━━━━━━━━━━━ 3:13:06 63s/step - accuracy: 0.1875 - loss: 1.2813
# I0000 00:00:1747082800.071620     118 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 681ms/step - accuracy: 0.2587 - loss: 1.6936
# Epoch 1: val_accuracy improved from -inf to 0.23816, saving model to best_vit_model.keras
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 230s 907ms/step - accuracy: 0.2590 - loss: 1.6928 - val_accuracy: 0.2382 - val_loss: 2.0020 - learning_rate: 1.0000e-04
# Epoch 2/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - accuracy: 0.3936 - loss: 1.3486
# Epoch 2: val_accuracy improved from 0.23816 to 0.59608, saving model to best_vit_model.keras
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 132s 696ms/step - accuracy: 0.3942 - loss: 1.3479 - val_accuracy: 0.5961 - val_loss: 0.9506 - learning_rate: 1.0000e-04
# Epoch 3/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 508ms/step - accuracy: 0.6547 - loss: 0.9638
# Epoch 3: val_accuracy did not improve from 0.59608
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 121s 635ms/step - accuracy: 0.6549 - loss: 0.9635 - val_accuracy: 0.5115 - val_loss: 1.5350 - learning_rate: 1.0000e-04
# Epoch 4/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 504ms/step - accuracy: 0.6849 - loss: 0.9420
# Epoch 4: val_accuracy improved from 0.59608 to 0.74560, saving model to best_vit_model.keras
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 124s 647ms/step - accuracy: 0.6852 - loss: 0.9414 - val_accuracy: 0.7456 - val_loss: 0.6386 - learning_rate: 1.0000e-04
# Epoch 5/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step - accuracy: 0.7935 - loss: 0.7074
# Epoch 5: val_accuracy improved from 0.74560 to 0.80717, saving model to best_vit_model.keras
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 120s 627ms/step - accuracy: 0.7936 - loss: 0.7073 - val_accuracy: 0.8072 - val_loss: 0.4497 - learning_rate: 1.0000e-04
# Epoch 6/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 502ms/step - accuracy: 0.8130 - loss: 0.6653
# Epoch 6: val_accuracy improved from 0.80717 to 0.83897, saving model to best_vit_model.keras
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 121s 634ms/step - accuracy: 0.8131 - loss: 0.6651 - val_accuracy: 0.8390 - val_loss: 0.3946 - learning_rate: 1.0000e-04
# Epoch 7/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 503ms/step - accuracy: 0.8239 - loss: 0.6597
# Epoch 7: val_accuracy did not improve from 0.83897
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 122s 638ms/step - accuracy: 0.8240 - loss: 0.6594 - val_accuracy: 0.8160 - val_loss: 0.4920 - learning_rate: 1.0000e-04
# Epoch 8/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 505ms/step - accuracy: 0.8357 - loss: 0.6376
# Epoch 8: val_accuracy did not improve from 0.83897
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 121s 633ms/step - accuracy: 0.8356 - loss: 0.6376 - val_accuracy: 0.7997 - val_loss: 0.4870 - learning_rate: 1.0000e-04
# Epoch 9/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step - accuracy: 0.8395 - loss: 0.5991
# Epoch 9: val_accuracy did not improve from 0.83897
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 119s 626ms/step - accuracy: 0.8395 - loss: 0.5991 - val_accuracy: 0.8248 - val_loss: 0.4606 - learning_rate: 1.0000e-04
# Epoch 10/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 530ms/step - accuracy: 0.8678 - loss: 0.5205
# Epoch 10: val_accuracy did not improve from 0.83897
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 126s 664ms/step - accuracy: 0.8678 - loss: 0.5208 - val_accuracy: 0.8173 - val_loss: 0.5207 - learning_rate: 1.0000e-04
# Epoch 11/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 502ms/step - accuracy: 0.8738 - loss: 0.5143
# Epoch 11: val_accuracy improved from 0.83897 to 0.87889, saving model to best_vit_model.keras
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 121s 633ms/step - accuracy: 0.8738 - loss: 0.5145 - val_accuracy: 0.8789 - val_loss: 0.3294 - learning_rate: 1.0000e-04
# Epoch 12/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.8661 - loss: 0.5517
# Epoch 12: val_accuracy did not improve from 0.87889
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 123s 640ms/step - accuracy: 0.8661 - loss: 0.5517 - val_accuracy: 0.8742 - val_loss: 0.3106 - learning_rate: 1.0000e-04
# Epoch 13/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 509ms/step - accuracy: 0.8585 - loss: 0.5674
# Epoch 13: val_accuracy improved from 0.87889 to 0.88701, saving model to best_vit_model.keras
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 125s 656ms/step - accuracy: 0.8586 - loss: 0.5674 - val_accuracy: 0.8870 - val_loss: 0.2975 - learning_rate: 1.0000e-04
# Epoch 14/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 509ms/step - accuracy: 0.8791 - loss: 0.5427
# Epoch 14: val_accuracy improved from 0.88701 to 0.88972, saving model to best_vit_model.keras
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 125s 655ms/step - accuracy: 0.8791 - loss: 0.5426 - val_accuracy: 0.8897 - val_loss: 0.2817 - learning_rate: 1.0000e-04
# Epoch 15/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 518ms/step - accuracy: 0.8845 - loss: 0.4866
# Epoch 15: val_accuracy improved from 0.88972 to 0.89175, saving model to best_vit_model.keras
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 125s 654ms/step - accuracy: 0.8845 - loss: 0.4867 - val_accuracy: 0.8917 - val_loss: 0.2730 - learning_rate: 1.0000e-04
# Epoch 16/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 509ms/step - accuracy: 0.8740 - loss: 0.5006
# Epoch 16: val_accuracy did not improve from 0.89175
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 121s 638ms/step - accuracy: 0.8740 - loss: 0.5007 - val_accuracy: 0.8857 - val_loss: 0.3069 - learning_rate: 1.0000e-04
# Epoch 17/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - accuracy: 0.8918 - loss: 0.4656
# Epoch 17: val_accuracy did not improve from 0.89175
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 122s 640ms/step - accuracy: 0.8917 - loss: 0.4659 - val_accuracy: 0.8545 - val_loss: 0.3373 - learning_rate: 1.0000e-04
# Epoch 18/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 523ms/step - accuracy: 0.8878 - loss: 0.4904
# Epoch 18: val_accuracy did not improve from 0.89175
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 126s 653ms/step - accuracy: 0.8878 - loss: 0.4907 - val_accuracy: 0.8139 - val_loss: 0.5119 - learning_rate: 1.0000e-04
# Epoch 19/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 505ms/step - accuracy: 0.8855 - loss: 0.5109
# Epoch 19: val_accuracy improved from 0.89175 to 0.89581, saving model to best_vit_model.keras
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 121s 635ms/step - accuracy: 0.8855 - loss: 0.5109 - val_accuracy: 0.8958 - val_loss: 0.2788 - learning_rate: 1.0000e-04
# Epoch 20/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step - accuracy: 0.8993 - loss: 0.4736
# Epoch 20: val_accuracy improved from 0.89581 to 0.89851, saving model to best_vit_model.keras
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 122s 641ms/step - accuracy: 0.8993 - loss: 0.4737 - val_accuracy: 0.8985 - val_loss: 0.2557 - learning_rate: 1.0000e-04
# Epoch 21/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 518ms/step - accuracy: 0.9093 - loss: 0.4693
# Epoch 21: val_accuracy did not improve from 0.89851
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 125s 651ms/step - accuracy: 0.9093 - loss: 0.4693 - val_accuracy: 0.8863 - val_loss: 0.2940 - learning_rate: 1.0000e-04
# Epoch 22/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - accuracy: 0.8931 - loss: 0.4972
# Epoch 22: val_accuracy did not improve from 0.89851
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 123s 645ms/step - accuracy: 0.8932 - loss: 0.4972 - val_accuracy: 0.8965 - val_loss: 0.2545 - learning_rate: 1.0000e-04
# Epoch 23/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - accuracy: 0.9076 - loss: 0.4411
# Epoch 23: val_accuracy did not improve from 0.89851
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 124s 651ms/step - accuracy: 0.9076 - loss: 0.4413 - val_accuracy: 0.8972 - val_loss: 0.2709 - learning_rate: 1.0000e-04
# Epoch 24/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - accuracy: 0.8973 - loss: 0.4543
# Epoch 24: val_accuracy did not improve from 0.89851
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 122s 639ms/step - accuracy: 0.8973 - loss: 0.4544 - val_accuracy: 0.8484 - val_loss: 0.3939 - learning_rate: 1.0000e-04
# Epoch 25/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 504ms/step - accuracy: 0.8896 - loss: 0.5042
# Epoch 25: val_accuracy improved from 0.89851 to 0.91407, saving model to best_vit_model.keras
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 122s 639ms/step - accuracy: 0.8896 - loss: 0.5040 - val_accuracy: 0.9141 - val_loss: 0.2311 - learning_rate: 1.0000e-04
# Epoch 26/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 519ms/step - accuracy: 0.9105 - loss: 0.4405
# Epoch 26: val_accuracy did not improve from 0.91407
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 125s 656ms/step - accuracy: 0.9105 - loss: 0.4406 - val_accuracy: 0.8363 - val_loss: 0.3951 - learning_rate: 1.0000e-04
# Epoch 27/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - accuracy: 0.8876 - loss: 0.5433
# Epoch 27: val_accuracy did not improve from 0.91407
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 124s 645ms/step - accuracy: 0.8877 - loss: 0.5430 - val_accuracy: 0.9141 - val_loss: 0.2110 - learning_rate: 1.0000e-04
# Epoch 28/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 536ms/step - accuracy: 0.9130 - loss: 0.4483
# Epoch 28: val_accuracy did not improve from 0.91407
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 129s 674ms/step - accuracy: 0.9131 - loss: 0.4483 - val_accuracy: 0.8802 - val_loss: 0.3331 - learning_rate: 1.0000e-04
# Epoch 29/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 508ms/step - accuracy: 0.9114 - loss: 0.4533
# Epoch 29: val_accuracy did not improve from 0.91407
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 121s 634ms/step - accuracy: 0.9114 - loss: 0.4533 - val_accuracy: 0.9093 - val_loss: 0.2155 - learning_rate: 1.0000e-04
# Epoch 30/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - accuracy: 0.9106 - loss: 0.4322
# Epoch 30: val_accuracy did not improve from 0.91407
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 121s 635ms/step - accuracy: 0.9105 - loss: 0.4324 - val_accuracy: 0.8965 - val_loss: 0.2644 - learning_rate: 1.0000e-04
# Epoch 31/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - accuracy: 0.9114 - loss: 0.4242
# Epoch 31: val_accuracy did not improve from 0.91407
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 124s 647ms/step - accuracy: 0.9114 - loss: 0.4243 - val_accuracy: 0.8681 - val_loss: 0.4069 - learning_rate: 1.0000e-04
# Epoch 32/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 523ms/step - accuracy: 0.9035 - loss: 0.4815
# Epoch 32: val_accuracy did not improve from 0.91407
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 128s 673ms/step - accuracy: 0.9035 - loss: 0.4813 - val_accuracy: 0.9080 - val_loss: 0.2225 - learning_rate: 1.0000e-04
# Epoch 33/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 555ms/step - accuracy: 0.9287 - loss: 0.4086
# Epoch 33: val_accuracy did not improve from 0.91407
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 132s 694ms/step - accuracy: 0.9287 - loss: 0.4085 - val_accuracy: 0.9080 - val_loss: 0.2556 - learning_rate: 2.0000e-05
# Epoch 34/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - accuracy: 0.9270 - loss: 0.3978
# Epoch 34: val_accuracy improved from 0.91407 to 0.92760, saving model to best_vit_model.keras
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 128s 667ms/step - accuracy: 0.9270 - loss: 0.3976 - val_accuracy: 0.9276 - val_loss: 0.1889 - learning_rate: 2.0000e-05
# Epoch 35/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 527ms/step - accuracy: 0.9415 - loss: 0.3365
# Epoch 35: val_accuracy improved from 0.92760 to 0.93099, saving model to best_vit_model.keras
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 127s 666ms/step - accuracy: 0.9415 - loss: 0.3367 - val_accuracy: 0.9310 - val_loss: 0.1757 - learning_rate: 2.0000e-05
# Epoch 36/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 508ms/step - accuracy: 0.9325 - loss: 0.3310
# Epoch 36: val_accuracy did not improve from 0.93099
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 124s 646ms/step - accuracy: 0.9326 - loss: 0.3311 - val_accuracy: 0.9222 - val_loss: 0.2063 - learning_rate: 2.0000e-05
# Epoch 37/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 510ms/step - accuracy: 0.9395 - loss: 0.3597
# Epoch 37: val_accuracy did not improve from 0.93099
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 122s 638ms/step - accuracy: 0.9395 - loss: 0.3597 - val_accuracy: 0.9222 - val_loss: 0.2050 - learning_rate: 2.0000e-05
# Epoch 38/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 508ms/step - accuracy: 0.9387 - loss: 0.3544
# Epoch 38: val_accuracy did not improve from 0.93099
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 122s 639ms/step - accuracy: 0.9387 - loss: 0.3544 - val_accuracy: 0.9120 - val_loss: 0.2484 - learning_rate: 2.0000e-05
# Epoch 39/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step - accuracy: 0.9433 - loss: 0.3388
# Epoch 39: val_accuracy did not improve from 0.93099
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 119s 622ms/step - accuracy: 0.9433 - loss: 0.3388 - val_accuracy: 0.9141 - val_loss: 0.2254 - learning_rate: 2.0000e-05
# Epoch 40/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 501ms/step - accuracy: 0.9427 - loss: 0.3671
# Epoch 40: val_accuracy did not improve from 0.93099
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 121s 634ms/step - accuracy: 0.9427 - loss: 0.3669 - val_accuracy: 0.9235 - val_loss: 0.1964 - learning_rate: 2.0000e-05
# Epoch 41/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 502ms/step - accuracy: 0.9470 - loss: 0.3191
# Epoch 41: val_accuracy did not improve from 0.93099
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 120s 630ms/step - accuracy: 0.9470 - loss: 0.3192 - val_accuracy: 0.9290 - val_loss: 0.1944 - learning_rate: 4.0000e-06
# Epoch 42/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 513ms/step - accuracy: 0.9489 - loss: 0.3064
# Epoch 42: val_accuracy did not improve from 0.93099
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 125s 654ms/step - accuracy: 0.9488 - loss: 0.3064 - val_accuracy: 0.9249 - val_loss: 0.1969 - learning_rate: 4.0000e-06
# Epoch 43/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 509ms/step - accuracy: 0.9446 - loss: 0.3211
# Epoch 43: val_accuracy did not improve from 0.93099
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 123s 643ms/step - accuracy: 0.9446 - loss: 0.3210 - val_accuracy: 0.9249 - val_loss: 0.2040 - learning_rate: 4.0000e-06
# Epoch 44/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - accuracy: 0.9498 - loss: 0.3066
# Epoch 44: val_accuracy improved from 0.93099 to 0.93572, saving model to best_vit_model.keras
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 124s 646ms/step - accuracy: 0.9498 - loss: 0.3066 - val_accuracy: 0.9357 - val_loss: 0.1715 - learning_rate: 4.0000e-06
# Epoch 45/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step - accuracy: 0.9478 - loss: 0.2788
# Epoch 45: val_accuracy did not improve from 0.93572
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 118s 617ms/step - accuracy: 0.9477 - loss: 0.2789 - val_accuracy: 0.9256 - val_loss: 0.1995 - learning_rate: 4.0000e-06
# Epoch 46/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 502ms/step - accuracy: 0.9493 - loss: 0.3002
# Epoch 46: val_accuracy did not improve from 0.93572
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 120s 630ms/step - accuracy: 0.9493 - loss: 0.3002 - val_accuracy: 0.9310 - val_loss: 0.1932 - learning_rate: 4.0000e-06
# Epoch 47/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 502ms/step - accuracy: 0.9515 - loss: 0.2865
# Epoch 47: val_accuracy did not improve from 0.93572
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 122s 638ms/step - accuracy: 0.9515 - loss: 0.2865 - val_accuracy: 0.9303 - val_loss: 0.1909 - learning_rate: 4.0000e-06
# Epoch 48/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - accuracy: 0.9463 - loss: 0.3036
# Epoch 48: val_accuracy did not improve from 0.93572
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 121s 634ms/step - accuracy: 0.9463 - loss: 0.3036 - val_accuracy: 0.9202 - val_loss: 0.2106 - learning_rate: 4.0000e-06
# Epoch 49/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 505ms/step - accuracy: 0.9494 - loss: 0.2945
# Epoch 49: val_accuracy did not improve from 0.93572
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 1e-06.
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 120s 629ms/step - accuracy: 0.9494 - loss: 0.2945 - val_accuracy: 0.9202 - val_loss: 0.1962 - learning_rate: 4.0000e-06
# Epoch 50/50
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 504ms/step - accuracy: 0.9497 - loss: 0.2849
# Epoch 50: val_accuracy did not improve from 0.93572
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 120s 630ms/step - accuracy: 0.9497 - loss: 0.2850 - val_accuracy: 0.9344 - val_loss: 0.1837 - learning_rate: 1.0000e-06
# Restoring model weights from the end of the best epoch: 44.

# %%
# Plot training history
print("\nPlotting training history...")
plot_training_history(history)

# Evaluate the model
print("\nEvaluating model...")
val_loss, val_accuracy = evaluate_model(model, valData)

# Load the best model weights
print("\nLoading best model weights...")
model.load_weights('best_vit_model.keras')
# Out:
# Plotting training history...
# Evaluating model...
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 24s 506ms/step - accuracy: 0.9594 - loss: 0.1374
# Validation Loss: 0.1742
# Validation Accuracy: 0.9405
#
# Loading best model weights...

# %%
# Create submission file
print("\nCreating submission file...")
submission_df = create_submission_csv(model, testData, '/kaggle/working/submission.csv')

# Save model architecture and weights separately for easy loading later
print("\nSaving model for future use...")
model.save('/kaggle/working/fruit_quality_vit_complete.keras')
# Out:
# Creating submission file...
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 118s 1s/step
# Submission saved to /kaggle/working/submission.csv
#
# First 10 predictions:
#               ImageID  Class
# 0     testimage_1.jpg      2
# 1    testimage_10.jpg      0
# 2   testimage_100.jpg      0
# 3  testimage_1000.jpg      2
# 4  testimage_1001.jpg      0
# 5  testimage_1002.jpg      2
# 6  testimage_1003.jpg      1
# 7  testimage_1004.jpg      1
# 8  testimage_1005.jpg      2
# 9  testimage_1006.jpg      2
#
# Saving model for future use...

# %%
# Save class indices for future reference
import json
class_indices = trainData.class_indices
with open('class_indices.json', 'w') as f:
    json.dump(class_indices, f)

print("\nTraining completed successfully!")
print(f"Final validation accuracy: {val_accuracy:.4f}")
print("Files saved:")
print("- best_vit_model.keras (best model weights)")
print("- fruit_quality_vit_complete.keras (complete model)")
print("- submission.csv (Kaggle submission)")
print("- class_indices.json (class mappings)")

# Additional metrics and visualization
print("\nGetting final predictions on validation set...")
val_predictions = model.predict(valData, verbose=1)
val_predicted_classes = np.argmax(val_predictions, axis=1)

# Get actual labels for validation set
val_labels = []
for i in range(len(valData)):
    batch_x, batch_y = valData[i]
    val_labels.extend(batch_y)
valData.reset()

val_labels = np.array(val_labels[:len(val_predicted_classes)])

# Classification report
from sklearn.metrics import classification_report, confusion_matrix
class_names = list(trainData.class_indices.keys())

print("\nClassification Report:")
print(classification_report(val_labels, val_predicted_classes, target_names=class_names))

# Confusion matrix
print("\nCreating confusion matrix...")
cm = confusion_matrix(val_labels, val_predicted_classes)

plt.figure(figsize=(12, 10))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names, rotation=90)
plt.yticks(tick_marks, class_names)
plt.ylabel('True Label')
plt.xlabel('Predicted Label')

# Add numbers to confusion matrix
thresh = cm.max() / 2.
for i, j in np.ndindex(cm.shape):
    plt.text(j, i, format(cm[i, j], 'd'),
             horizontalalignment="center",
             color="white" if cm[i, j] > thresh else "black")

plt.tight_layout()
plt.show()
# Out:
# Training completed successfully!
# Final validation accuracy: 0.9405
# Files saved:
# - best_vit_model.keras (best model weights)
# - fruit_quality_vit_complete.keras (complete model)
# - submission.csv (Kaggle submission)
# - class_indices.json (class mappings)
#
# Getting final predictions on validation set...
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 39s 790ms/step
#
# Classification Report:
#                       precision    recall  f1-score   support
#
#      banana_overripe       0.96      0.95      0.95       310
#          banana_ripe       0.92      0.96      0.94       320
#        banana_rotten       0.97      0.94      0.95       441
#        banana_unripe       0.99      0.98      0.99       304
# tomato_fully_ripened       0.39      1.00      0.56        11
#         tomato_green       0.92      0.62      0.74        74
#  tomato_half_ripened       0.40      0.56      0.47        18
#
#             accuracy                           0.94      1478
#            macro avg       0.79      0.86      0.80      1478
#         weighted avg       0.95      0.94      0.94      1478
#
#
# Creating confusion matrix...

# %%
"""
Exam Day Prediction Script
This script loads the trained model and generates predictions for the test samples
Run this script on exam day with the test data
"""

import tensorflow as tf
import numpy as np
import pandas as pd
import json
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import Model
from tensorflow.keras.models import load_model

# Custom layer imports (needed for loading the model)
from vit_tensorflow_complete import (
    PatchCreation, 
    PatchEmbedding, 
    PositionEmbedding, 
    TransformerEncoderBlock
)

# Configuration
IMG_SIZE = (224, 224)
BATCH_SIZE = 32

def load_trained_model(model_path):
    """Load the trained Vision Transformer model"""
    # Define custom objects for loading
    custom_objects = {
        'PatchCreation': PatchCreation,
        'PatchEmbedding': PatchEmbedding, 
        'PositionEmbedding': PositionEmbedding,
        'TransformerEncoderBlock': TransformerEncoderBlock
    }
    
    print(f"Loading model from {model_path}...")
    model = load_model(model_path, custom_objects=custom_objects)
    print("Model loaded successfully!")
    return model

def prepare_test_data(test_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE):
    """Prepare test data for prediction"""
    test_datagen = ImageDataGenerator(rescale=1./255)
    
    test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=target_size,
        batch_size=batch_size,
        class_mode=None,  # No labels
        shuffle=False     # Keep order for submission
    )
    
    return test_generator

def make_predictions(model, test_generator, class_indices_path='class_indices.json'):
    """Generate predictions and create submission file"""
    print("Making predictions...")
    
    # Load class indices
    with open(class_indices_path, 'r') as f:
        class_indices = json.load(f)
    
    # Invert class_indices to get index -> class_name mapping
    idx_to_class = {v: k for k, v in class_indices.items()}
    
    # Generate predictions
    predictions = model.predict(test_generator, verbose=1)
    predicted_classes = np.argmax(predictions, axis=1)
    
    # Get filenames and extract IDs
    filenames = test_generator.filenames
    ids = [os.path.splitext(os.path.basename(f))[0] for f in filenames]
    
    # Map predictions to class names
    predicted_labels = [idx_to_class[pred] for pred in predicted_classes]
    
    # Create submission dataframe
    submission_df = pd.DataFrame({
        'id': ids,
        'label': predicted_labels
    })
    
    return submission_df

def main(test_dir, model_path='best_vit_model.keras', output_file='exam_submission.csv'):
    """Main function to run predictions"""
    print("=== Exam Day Prediction Script ===")
    print(f"Test directory: {test_dir}")
    print(f"Model path: {model_path}")
    print(f"Output file: {output_file}")
    
    # Load model
    model = load_trained_model(model_path)
    
    # Prepare test data
    test_generator = prepare_test_data(test_dir)
    print(f"Found {test_generator.samples} test samples")
    
    # Make predictions
    submission_df = make_predictions(model, test_generator)
    
    # Save submission
    submission_df.to_csv(output_file, index=False)
    print(f"\nSubmission saved to {output_file}")
    
    # Show sample predictions
    print("\nSample predictions:")
    print(submission_df.head(10))
    
    # Show class distribution in predictions
    print("\nPredicted class distribution:")
    print(submission_df['label'].value_counts())
    
    return submission_df

# Example usage
if __name__ == "__main__":
    # Update these paths for your specific setup
    TEST_DIR = '/kaggle/input/fine-grained-fruit-quality-assessment/test/testNew'  # Update this path
    MODEL_PATH = '/kaggle/input/fine-grained-fruit-quality-assessment/best_vit_model.keras'
    OUTPUT_FILE = '/kaggle/working/exam_submission.csv'
    
    # Run predictions
    submission = main(TEST_DIR, MODEL_PATH, OUTPUT_FILE)

# Alternative: Quick prediction script for different model formats
def quick_predict(test_dir, model_path):
    """Quick prediction function that handles different model formats"""
    try:
        # Try loading with custom objects first
        model = load_trained_model(model_path)
    except:
        try:
            # Try loading as SavedModel
            print("Trying to load as SavedModel...")
            model = tf.keras.models.load_model(model_path)
        except:
            # Try loading weights only
            print("Trying to load weights only...")
            # You would need to recreate the model architecture here
            # model = create_vit_model(...)  # Uncomment and provide parameters
            # model.load_weights(model_path)
            raise ValueError("Could not load model. Please check the model path.")
    
    # Prepare data and make predictions
    test_gen = prepare_test_data(test_dir)
    submission = make_predictions(model, test_gen)
    
    return submission

# Debugging functions
def verify_model_loading(model_path):
    """Verify that the model can be loaded properly"""
    try:
        model = load_trained_model(model_path)
        print("✓ Model loaded successfully")
        print(f"Model input shape: {model.input_shape}")
        print(f"Model output shape: {model.output_shape}")
        return True
    except Exception as e:
        print(f"✗ Error loading model: {e}")
        return False

def test_prediction_pipeline(test_dir, model_path, n_samples=5):
    """Test the prediction pipeline with a small subset"""
    print("Testing prediction pipeline...")
    
    # Load model
    model = load_trained_model(model_path)
    
    # Create test generator with small batch
    test_gen = prepare_test_data(test_dir, batch_size=n_samples)
    
    # Get one batch
    test_batch = next(test_gen)
    
    # Make prediction
    pred = model.predict(test_batch)
    print(f"Prediction shape: {pred.shape}")
    print(f"Sample prediction: {pred[0]}")
    
    return pred
